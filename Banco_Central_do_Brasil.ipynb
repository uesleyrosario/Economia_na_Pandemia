# %% [markdown]
# #                             Banco Central do Brasil

# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,4)

# %% [markdown]
# # Obtendo Dados através da API do Banco Central do Brasil

# %%
def consulta_bc(codigo_bcb):
  url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# %% [markdown]
# # API do Banco Central do Brasil

# %% [markdown]
# ###Índice Nacional de Preços ao Consumidor - INPC

# %%
INPC = consulta_bc(188)
plt.title('Índice Nacional de Preços ao Consumidor - INPC')
plt.plot(INPC)
INPC.tail(1)
# Out:
#             valor
# data
# 2020-06-01    0.3

# %% [markdown]
# ###Índice Geral de Preços do Mercado - IGP-M

# %%
IGPM = consulta_bc(189)
plt.title('Índice Geral de Preços do Mercado - IGP-M')
plt.plot(IGPM)
IGPM.tail(1)
# Out:
#             valor
# data
# 2020-07-01   2.23

# %% [markdown]
# ###Índice Nacional de Custo de Construção - INCC

# %%
INCC = consulta_bc(192)
plt.title('Índice Nacional de Custo de Construção - INCC')
plt.plot(INCC)
INCC.tail(1)
# Out:
#             valor
# data
# 2020-07-01   1.17

# %% [markdown]
# ###Custo da Cesta Básica em São Paulo

# %%
CCBSP = consulta_bc(7493)
plt.title('Custo da Cesta Básica em São Paulo')
plt.plot(CCBSP)
CCBSP.tail(1)
# Out:
#              valor
# data
# 2020-06-01  547.03

# %% [markdown]
# ###Índice de Preço de Matérias Primas

# %%
IC_Br = consulta_bc(27574)
plt.title('Índice de Preço de Matérias Primas')
plt.plot(IC_Br)
IC_Br.tail(1)
# Out:
#              valor
# data
# 2020-07-01  229.77

# %% [markdown]
# ###Índice de Valores de Garantia de Imóveis Residenciais Financiados

# %%
IVGR = consulta_bc(21340)
plt.title('Índice de Valores de Garantia de Imóveis Residenciais Financiados')
plt.plot(IVGR)
IVGR.tail(1)
# Out:
#              valor
# data
# 2020-05-01  555.69

# %% [markdown]
# ###Salário Mínimo

# %%
Salário_Mínimo = consulta_bc(1619)
plt.title('Salário Mínimo')
plt.plot(Salário_Mínimo)
Salário_Mínimo.tail(1)
# Out:
#              valor
# data
# 2020-07-01  1045.0

# %% [markdown]
# ###Rendimento Salarial Médio no Setor Privado

# %%
RSMSPRI = consulta_bc(24385)
plt.title('Rendimento Salarial Médio no Setor Privado')
plt.plot(RSMSPRI)
RSMSPRI.tail(1)
# Out:
#               valor
# data
# 2020-06-01  2136.11

# %% [markdown]
# ###Rendimento Salarial Médio no Setor Público

# %%
RSMSPU = consulta_bc(24386)
plt.title('Rendimento Salarial Médio no Setor Público')
plt.plot(RSMSPU)
RSMSPU.tail(1)
# Out:
#             valor
# data
# 2020-06-01   3776

# %% [markdown]
# ###Taxa de Desocupação

# %%
Taxa_de_desocupação_PNADC = consulta_bc(24369)
plt.title('Taxa de Desocupação')
plt.plot(Taxa_de_desocupação_PNADC)
Taxa_de_desocupação_PNADC.tail(1)
# Out:
#             valor
# data
# 2020-06-01   13.3

# %% [markdown]
# ###Pessoas em Idade de Trabalhar

# %%
Pessoas_em_idade_de_trabalhar = consulta_bc(24370)
plt.title('Pessoas em Idade de Trabalhar')
plt.plot(Pessoas_em_idade_de_trabalhar)
Pessoas_em_idade_de_trabalhar.tail(1)
# Out:
#              valor
# data
# 2020-06-01  173918

# %% [markdown]
# ###Pessoas Ocupadas

# %%
pessoas_ocupadas = consulta_bc(24379)
plt.title('Pessoas Ocupadas')
plt.plot(pessoas_ocupadas)
pessoas_ocupadas.tail(1)
# Out:
#             valor
# data
# 2020-06-01  83347

# %% [markdown]
# ###Pessoas Desocupadas

# %%
pessoas_desocupadas = consulta_bc(24380)
plt.title('Pessoas Desocupadas')
plt.plot(pessoas_desocupadas)
pessoas_desocupadas.tail(1)
# Out:
#             valor
# data
# 2020-06-01  12791

# %% [markdown]
# ###Vendas Total Varejo

# %%
vendas_varejo_total_Brasil = consulta_bc(1455)
plt.title('Vendas Total Varejo')
plt.plot(vendas_varejo_total_Brasil)
vendas_varejo_total_Brasil.tail(1)
# Out:
#             valor
# data
# 2020-05-01   86.0

# %% [markdown]
# ###Reservas Internacionais

# %%
reservas_internacionais = consulta_bc(13621)
plt.title('Reservas Internacionais')
plt.plot(reservas_internacionais)
reservas_internacionais.tail(1)
# Out:
#              valor
# data
# 2020-08-05  357339

# %% [markdown]
# ###Produto Interno Bruto

# %%
PIB_acumulado_dos_últimos_12_meses_valores_correntes = consulta_bc(4382)
plt.title('Produto Interno Bruto')
plt.plot(PIB_acumulado_dos_últimos_12_meses_valores_correntes)
PIB_acumulado_dos_últimos_12_meses_valores_correntes.tail(1)
# Out:
#                 valor
# data
# 2020-06-01  7193913.1

# %% [markdown]
# ###Indicadores da Produção - Geral

# %%
IPG = consulta_bc(21859)
plt.title('Indicadores da Produção - Geral')
plt.plot(IPG)
IPG.tail(1)
# Out:
#             valor
# data
# 2020-06-01   78.1

# %% [markdown]
# ###Produção de Automóveis e Comerciais Leves

# %%
produção_automoveis_e_comercias_leves = consulta_bc(1374)
plt.title('Produção de Automóveis e Comerciais Leves')
plt.plot(produção_automoveis_e_comercias_leves)
produção_automoveis_e_comercias_leves.tail(1)
# Out:
#             valor
# data
# 2020-06-01  91732

# %% [markdown]
# ###Produção de Caminhões

# %%
produção_caminhões = consulta_bc(1375)
plt.title('Produção de Caminhões')
plt.plot(produção_caminhões)
produção_caminhões.tail(1)
# Out:
#             valor
# data
# 2020-06-01   5634

# %% [markdown]
# ###Produção de Ônibus

# %%
produção_ônibus = consulta_bc(1376)
plt.title('Produção de Ônibus')
plt.plot(produção_ônibus)
produção_ônibus.tail(1)
# Out:
#             valor
# data
# 2020-06-01   1342

# %% [markdown]
# ###Produção de máquinas agrícolas (total)

# %%
PMAT = consulta_bc(1388)
plt.title('Produção de máquinas agrícolas (total)')
plt.plot(PMAT)
PMAT.tail(1)
# Out:
#             valor
# data
# 2020-06-01   3319

# %% [markdown]
# ###Vendas Automóveis

# %%
vendas_automóveis = consulta_bc(7384)
plt.title('Vendas Automóveis')
plt.plot(vendas_automóveis)
vendas_automóveis.tail(1)
# Out:
#              valor
# data
# 2020-07-01  134944

# %% [markdown]
# ###Vendas de Comerciais Leves

# %%
vendas_comerciais_leves = consulta_bc(7385)
plt.title('Vendas de Comerciais Leves')
plt.plot(vendas_comerciais_leves)
vendas_comerciais_leves.tail(1)
# Out:
#             valor
# data
# 2020-07-01  28139

# %% [markdown]
# ###Vendas de Caminhões

# %%
vendas_caminhões = consulta_bc(7386)
plt.title('Vendas de Caminhões')
plt.plot(vendas_caminhões)
vendas_caminhões.tail(1)
# Out:
#             valor
# data
# 2020-07-01   9522

# %% [markdown]
# ###Vendas de ônibus

# %%
vendas_ônibus = consulta_bc(7387)
plt.title('Vendas de ônibus')
plt.plot(vendas_ônibus)
vendas_ônibus.tail(1)
# Out:
#             valor
# data
# 2020-07-01   1893

# %% [markdown]
# ###Taxa Selic Meta

# %%
selic_meta = consulta_bc(432)
plt.title('Meta Selic')
plt.plot(selic_meta)
selic_meta.tail(1)
# Out:
#             valor
# data
# 2020-09-16    2.0

# %% [markdown]
# # CDI vs IBOV

# %%
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf

# %%
ibov = yf.download(tickers='^BVSP')[['Adj Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov_retorno = ibov.pct_change()

# %%
cdi = consulta_bc(12)

# %%
data_inicio = '2018-01-01'

# %%
ibov_retorno_acumulado = (1 + ibov_retorno[ibov_retorno.index >= data_inicio]).cumprod()
ibov_retorno_acumulado.iloc[0] = 1

# %%
cdi_acumulado = (1 + cdi[cdi.index >= data_inicio] / 100).cumprod()
cdi_acumulado.iloc[0] = 1

# %%
fig, ax = plt.subplots()
plt.title('IBOV & CDI')
ax.plot(ibov_retorno_acumulado)
ax.plot(cdi_acumulado);
cdi_acumulado.tail(1), ibov_retorno_acumulado.tail(1)
# Out:
# (              valor
#  data
#  2020-08-06  1.15003,             Adj Close
#  Date
#  2020-08-07   1.347356)

# %% [markdown]
# ##Os dados usados estão dispníveis para consulta no Banco Central do Brasil.
# ##Nota: A qualidade da informação é responsabilidade da instituição.
